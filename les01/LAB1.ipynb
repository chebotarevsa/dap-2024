# %% [markdown]
# <a href="https://colab.research.google.com/github/Linkabli/dap-2024/blob/main/LAB1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная работа №1. Подготовка среды для анализа данных

# %% [markdown]
# # Задания к лабораторной работе.

# %% [markdown]
# **Задания:**
#
# 1.   Создайте учетную запись в сервисе GitHub
# 2.   Выполните форк репозитория https://github.com/chebotarevsa/dap-2024
# 3.   Создайте учетную запись в Google Colab
# 4.   Настройте интеграцию Google Colab и GitHub
# 5.   Создайте в Google Colab отчет о выполненой работе в виде файла rep.ipynb.
# 6.   Используйте Markdown разметку (заголовки, списки, форматированный текст,
#      ссылки)
# 7.   Сохраните отчет в ваш репозиторий github в директории ./les01
# 8.   Создайте pull request в репозиторий https://github.com/chebotarevsa/dap-2024. Название pull request должно иметь формат "<Номер лабораторной работы> <Номер группы> <ФИО>"
# 9.   Сдайте работу в системе "Пегас", в отчет укажите ссылку на pull request

# %% [markdown]
# # Задание 1.

# %% [markdown]
# Задание 1: Создайте учетную запись в сервисе GitHub.
#
# ---
# В результате выполнения данного задания была создана учетная запись в сервисе GitHub. Ссылка: [Linkabli](https://github.com/Linkabli).

# %% [markdown]
# # Задание 2.

# %% [markdown]
# Задание 2: Выполните форк репозитория https://github.com/chebotarevsa/dap-2024
#
# ---
# В результате выполнения данного задания был выполнени форк репозитория. Ссылка: [Linkabli/dap-2024](https://github.com/Linkabli/dap-2024).

# %% [markdown]
# # Задание 3.

# %% [markdown]
# Задание 3: Создайте учетную запись в Google Colab.
#
# ---
# В результате выполнения данного задания была создана учетная запись в сервисе Google Colab.
# Скриншот:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Задание 4.

# %% [markdown]
# Задание 4: Настройте интеграцию Google Colab и GitHub.
#
# ---
# В результате выполнения данного задания была настроена интеграция Google Colab и GitHub.
# Скриншот:![Снимок экрана 2024-09-19 113026.png](data:image/png;base64,...)

# %% [markdown]
# # Задание 5 и 6.

# %% [markdown]
# Задания:
# 5.   Создайте в Google Colab отчет о выполненой работе в виде файла rep.ipynb.
# 6.   Используйте Markdown разметку (заголовки, списки, форматированный текст, ссылки)
#
#
# ---
# Результат данных заданий был закреплен в конечном файле выполненной работы.

# %% [markdown]
# # Задание 7, 8 и 9.

# %% [markdown]
# Задание 7: Сохраните отчет в ваш репозиторий github в директории ./les01.
#
# Задание 8: Создайте pull request в репозиторий https://github.com/chebotarevsa/dap-2024. Название pull request должно иметь формат "<Номер лабораторной работы> <Номер группы> <ФИО>"
#
# Задание 9: Сдайте работу в системе "Пегас", в отчет укажите ссылку на pull request
#
#
# ---
# В результате выполнения данных заданий были выполнены последние этапы Лабораторной работы №1.
