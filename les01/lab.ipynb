# %% [markdown]
# <a href="https://colab.research.google.com/github/mihail1707/dap-2024/blob/main/les01/lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **`Отчет по лабораторной работе №1`**
#
# **Тема работы «Подготовка среды для анализа данных»**
#
# по дисциплине «Анализ данных на Python_ ВУК»
#
#                                                 студента  очного отделения
#
#                                                 3 курса 12002209 группы
#
#                                                 Петренко Михаила Викторовича

# %%
strs =["ab", "a"]
index = 0
for a in range(len(strs)):
    count = len(strs[0]);
    if count > len(strs[a]) :
        count = len(strs[a]);
        index = a
strStart = strs[index];
res ="";
for i in range((len(strStart))):
    print(i)
    for j in range(len(strs)):

          if len(strs[j]) == j:
            print(res)
            break
             # если строка закончилась
          if (len(strs[j])-1 == j) & (strStart[i] != strs[j][i]):
            print(res) ;
          if j == len(strs)-1: res+=strStart[i];
print("154",res) ;
# Out:
# 0
#
# 154

# %% [markdown]
# # Задания

# %% [markdown]
# 1.   Создайте учетную запись в сервисе GitHub
# 2.   Выполните форк репозитория https://github.com/chebotarevsa/dap-2024
#
# 1.   Создайте учетную запись в Google Colab
# 2.   Настройте интеграцию Google Colab и GitHub
#
# 1.   Создайте в Google Colab отчет о выполненой работе в виде файла rep.ipynb. Используйте Markdown разметку (заголовки, списки, форматированный текст, ссылки)
# 2.   Сохраните отчет в ваш репозиторий github в директории ./les01
#
# 1.   Создайте pull request в репозиторий https://github.com/chebotarevsa/dap-2024. Название pull request должно иметь формат "<Номер лабораторной работы> <Номер группы> <ФИО>"
# 2.   Сдайте работу в системе "Пегас", в отчет укажите ссылку на pull request

# %% [markdown]
# # Ход работы

# %% [markdown]
# 1) Создал учетную запись в GitHub и выполнил форк репозитория https://github.com/chebotarevsa/dap-2024 ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2) Создал учетную запись в Google Colab
# Настрол интеграцию Google Colab и GitHub
# ![image.png](data:image/png;base64,...)

# %%
class myclass:
  pass
