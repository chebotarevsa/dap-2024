# %% [markdown]
# # Лабораторная работа №1. Подготовка среды для анализа данных

# %% [markdown]
# ##Цель работы

# %% [markdown]
# Подготовка средств для анализа данных на Python.

# %% [markdown]
# ## Задание

# %% [markdown]
# 1. Создайте учетную запись в сервисе GitHub
# 2. Выполните форк репозитория https://github.com/chebotarevsa/dap-2024
# 3. Создайте учетную запись в [Google Colab](https://colab.research.google.com)
# 4. Настройте интеграцию Google Colab и GitHub
# 5. Создайте в Google Colab отчет о выполненой работе в виде файла rep.ipynb. Используйте Markdown разметку (заголовки, списки, форматированный текст, ссылки)
# 6. Сохраните отчет в ваш репозиторий github в директории ./les01
# 7. Создайте pull request в репозиторий https://github.com/chebotarevsa/dap-2024. Название pull request должно иметь формат "<Номер лабораторной работы>  <Номер группы> <ФИО>"
# 8. Сдайте работу в системе "Пегас", в отчет укажите ссылку на pull request

# %% [markdown]
# ## Вопросы

# %% [markdown]
# 1. Типы ячеек в Jupyter Notebook:
#
# *   Markdown (текстовы) ячейки;
# *   Python (кодовые) ячейки;
# 2.  Формирование иерархического списка Markdown:
#
# *   Для нумерованного списка просто используются номера и точки;
# *   Для маркированного списка используются *, - или + перед элементами списка;
#
# 3. В Markdown для оформления цитат используется символ >.
# >Если называть Python заменой BASIC, то тогда и трансформер Optimus Prime — это только замена грузовика. — Cory Dodt
#
# 4. Чтобы вставить многострочный блок кода, необходимо обренуть его тройными обратными кавычками (```):
# ```
# df2 = pd.DataFrame(
#     {
#         "A": 1.0,
#         "B": pd.Timestamp("20130102"),
#         "C": pd.Series(1, index=list(range(4)), dtype="float32"),
#         "D": np.array([3] * 4, dtype="int32"),
#         "E": pd.Categorical(["test", "train", "test", "train"]),
#         "F": "foo",
#     }
# )
# ```
# 5. В Markdown сущесвует 6 уровней заголовков.
# 6. Шаги процесса анализа данных:
#
#
#   6.1   Определение проблемы или выдвижение идей
#   6.2   Извлечение или сбор данных
#   6.3   Подготовка данных
#   6.4   Исследование и визуализация данных
#   6.5   Предсказательная модель
#   6.6   Проверка модели
#   6.7   Развертывание
#
#
# 7. Типы данных:
#   *   Структурированные данные
#   *   Неструктурированные данные
#   *   Полуструктурированные данные
# 8. Jupyter Notebook - интерактивный блокнот, первоначально являвшийся веб-реализацией и развитием IPython, ставший самостоятельным проектом, ориентированным на работу со множеством сред выполнения. Используется для:
#
#   *   Документации и аннотации
#   *   Интерактивного интерфейса
#   *   Поддержки различных языков программирования
#
# 9. Python популярен для анализа данных по следующим причинам:
#
#   1. Простота и читаемость
#   2. Обширные библиотеки
#
#     2.1 [NumPy](https://numpy.org)
#     2.2 [Pandas](https://pandas.pydata.org)
#     2.3 [TensorFlow](https://www.tensorflow.org)
#
#   3. Гибкость
#   4. Наличие Jupyter Notebook
#   5. Интеграция с другими инструментами
#
# 10. Использование Jupyter Notebook для анализа данных не является обязательным, но оно дает ряд преимуществ, которые сделали его популярным выбором:
#   *   Интерактивность
#   *   Документирование
#   *   Поддержка различных языков
#   *   Легкость в работе с визуализациями
#   *   Множество библиотек и расширений

# %% [markdown]
# ##Вывод

# %% [markdown]
# Были изучены средства для анализа данных на Python.
